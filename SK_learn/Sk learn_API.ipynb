# %%
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
rng = np.random.RandomState(35)
x= 10 * rng.rand(40)
y= 2 * x - 1 + rng.randn(40)

# %%
data = pd.DataFrame({'X': x, 'Y': y})
print(data.head())
# Out:
#           X          Y
# 0  4.580549   6.790195
# 1  3.083496   6.149635
# 2  2.314870   3.918440
# 3  2.774246   2.951180
# 4  8.172348  15.007651

# %%
X = x[:, np.newaxis]

# %%
model = LinearRegression(fit_intercept=True)

# %%
model.fit(X, y)
# Out:
# LinearRegression()

# %%
print(model.coef_)
print(model.intercept_)
# Out:
# [1.99839352]
# -0.9895459457775022

# %%
xfit = np.linspace(-1,11)
Xfit = xfit[:, np.newaxis]
yfit = model.predict(Xfit)

# %%
plt.scatter(x,y)
plt.plot(xfit, yfit)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
iris = sns.load_dataset('iris')
X_iris = iris.drop('species', axis=1)
Y_iris= iris['species']

# %%
from sklearn.decomposition import PCA
model = PCA(n_components=2)
model.fit(X_iris)
# Out:
# PCA(n_components=2)

# %%
X_2D = model.transform(X_iris)
iris['PCA1']= X_2D[:,0]
iris['PCA2']= X_2D[:,1]
sns.lmplot(x="PCA1",y="PCA2", hue= "species", data=iris,fit_reg=False)

# %%
import seaborn as sns

# %%
df =pd.read_csv(r"D:\AI\Advertising.csv")

# %%
df
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# TV            0
# radio         0
# newspaper     0
# sales         0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#        Unnamed: 0          TV       radio   newspaper       sales
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   100.500000  147.042500   23.264000   30.554000   14.022500
# std     57.879185   85.854236   14.846809   21.778621    5.217457
# min      1.000000    0.700000    0.000000    0.300000    1.600000
# 25%     50.750000   74.375000    9.975000   12.750000   10.375000
# 50%    100.500000  149.750000   22.900000   25.750000   12.900000
# 75%    150.250000  218.825000   36.525000   45.100000   17.400000
# max    200.000000  296.400000   49.600000  114.000000   27.000000

# %%
df.drop(df.columns[[0]],axis=1,inplace=True)

# %%
df
# Out:
#         TV  radio  newspaper  sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
sns.distplot(df.sales)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_20788\598165729.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.sales)
# <Axes: xlabel='sales', ylabel='Density'>

# %%
sns.distplot(df.radio)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_20788\2873433845.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.radio)
# <Axes: xlabel='radio', ylabel='Density'>

# %%
sns.distplot(df.newspaper)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_20788\3464958114.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.newspaper)
# <Axes: xlabel='newspaper', ylabel='Density'>

# %%
sns.displot(df.TV)
